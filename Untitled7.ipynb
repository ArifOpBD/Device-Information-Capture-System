# %% [markdown]
# <a href="https://colab.research.google.com/github/ArifOpBD/Device-Information-Capture-System/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
await main()
# Out:
# Quotex Signal Bot Started...
# [23:34:58] Checking for signals...
# Signal Detected: CALL - Strength: 2
# Waiting for 60 seconds...
# [23:35:59] Checking for signals...
# No strong signal found.
# Waiting for 60 seconds...
# [23:36:59] Checking for signals...
# Signal Detected: CALL - Strength: 2
# Waiting for 60 seconds...
# [23:38:00] Checking for signals...
# Signal Detected: CALL - Strength: 2
# Waiting for 60 seconds...
# [23:39:01] Checking for signals...
# Signal Detected: CALL - Strength: 2
# Waiting for 60 seconds...
# [23:40:02] Checking for signals...
# Signal Detected: PUT - Strength: 2
# Waiting for 60 seconds...
# [23:41:02] Checking for signals...
# No strong signal found.
# Waiting for 60 seconds...
# [23:42:02] Checking for signals...
# Signal Detected: CALL - Strength: 2
# Waiting for 60 seconds...

# %%
import numpy as np

def generate_sample_candles(num_candles: int = 100, initial_price: float = 1.20000) -> list:
    candles = []
    current_time = datetime.now() - pd.Timedelta(seconds=num_candles * CANDLE_PERIOD)
    price = initial_price

    for _ in range(num_candles):
        open_price = price

        # Simulate price movement
        change = np.random.uniform(-0.0005, 0.0005)
        close_price = open_price + change

        # Ensure high is above open/close and low is below open/close
        high_price = max(open_price, close_price) + np.random.uniform(0, 0.0002)
        low_price = min(open_price, close_price) - np.random.uniform(0, 0.0002)

        volume = np.random.randint(100, 1000)

        candles.append({
            "time": current_time.strftime("%Y-%m-%dT%H:%M:%SZ"),
            "open": open_price,
            "high": high_price,
            "low": low_price,
            "close": close_price,
            "volume": volume
        })

        price = close_price  # Update price for next candle
        current_time += pd.Timedelta(seconds=CANDLE_PERIOD)

    return candles

# Example usage:
# sample_candles = generate_sample_candles()
# print(sample_candles[:5])

# %%
sample_candles = generate_sample_candles(num_candles=CANDLE_COUNT)
signals = analyze_signals(sample_candles)
print("Generated Signals:")
print(signals)
# Out:
# Generated Signals:
# {'direction': None, 'strength': 0, 'details': {'rsi': np.float64(35.64), 'macd': np.float64(-0.00029), 'macd_sig': np.float64(-0.00032), 'ema9': np.float64(1.19654), 'ema21': np.float64(1.19675), 'call_score': 1, 'put_score': 1}}

# %%
# @title AI prompt cell

import ipywidgets as widgets
from IPython.display import display, HTML, Markdown,clear_output
from google.colab import ai

dropdown = widgets.Dropdown(
    options=[],
    layout={'width': 'auto'}
)

def update_model_list(new_options):
    dropdown.options = new_options
update_model_list(ai.list_models())

text_input = widgets.Textarea(
    placeholder='Ask me anything....',
    layout={'width': 'auto', 'height': '100px'},
)

button = widgets.Button(
    description='Submit Text',
    disabled=False,
    tooltip='Click to submit the text',
    icon='check'
)

output_area = widgets.Output(
     layout={'width': 'auto', 'max_height': '300px','overflow_y': 'scroll'}
)

def on_button_clicked(b):
    with output_area:
        output_area.clear_output(wait=False)
        accumulated_content = ""
        for new_chunk in ai.generate_text(prompt=text_input.value, model_name=dropdown.value, stream=True):
            if new_chunk is None:
                continue
            accumulated_content += new_chunk
            clear_output(wait=True)
            display(Markdown(accumulated_content))

button.on_click(on_button_clicked)
vbox = widgets.GridBox([dropdown, text_input, button, output_area])

display(HTML("""
<style>
.widget-dropdown select {
    font-size: 18px;
    font-family: "Arial", sans-serif;
}
.widget-textarea textarea {
    font-size: 18px;
    font-family: "Arial", sans-serif;
}
</style>
"""))
display(vbox)

# %%
# @title AI prompt cell

import ipywidgets as widgets
from IPython.display import display, HTML, Markdown,clear_output
from google.colab import ai

dropdown = widgets.Dropdown(
    options=[],
    layout={'width': 'auto'}
)

def update_model_list(new_options):
    dropdown.options = new_options
update_model_list(ai.list_models())

text_input = widgets.Textarea(
    placeholder='Ask me anything....',
    layout={'width': 'auto', 'height': '100px'},
)

button = widgets.Button(
    description='Submit Text',
    disabled=False,
    tooltip='Click to submit the text',
    icon='check'
)

output_area = widgets.Output(
     layout={'width': 'auto', 'max_height': '300px','overflow_y': 'scroll'}
)

def on_button_clicked(b):
    with output_area:
        output_area.clear_output(wait=False)
        accumulated_content = ""
        for new_chunk in ai.generate_text(prompt=text_input.value, model_name=dropdown.value, stream=True):
            if new_chunk is None:
                continue
            accumulated_content += new_chunk
            clear_output(wait=True)
            display(Markdown(accumulated_content))

button.on_click(on_button_clicked)
vbox = widgets.GridBox([dropdown, text_input, button, output_area])

display(HTML("""
<style>
.widget-dropdown select {
    font-size: 18px;
    font-family: "Arial", sans-serif;
}
.widget-textarea textarea {
    font-size: 18px;
    font-family: "Arial", sans-serif;
}
</style>
"""))
display(vbox)
